# %% [markdown]
# # 単語間の演算
# 単語ベクトルを使って、単語間の演算を行います。

# %% [markdown]
# ## データの読み込み、及びword2vecによる学習
# これまでと同様に、データの読み込み及びword2vecによる学習を行います。

# %%
import pickle
from gensim.models import word2vec

with open('wagahai_words.pickle', mode='rb') as f:
    wagahai_words = pickle.load(f)

print(wagahai_words)

# size : 中間層のニューロン数
# min_count : この値以下の出現回数の単語を無視
# window : 対象単語を中心とした前後の単語数
# iter : epochs数
# sg : CBOWを使うかskip-gramを使うか 0:CBOW 1:skip-gram
model = word2vec.Word2Vec(wagahai_words,
                          size=100,
                          min_count=5,
                          window=5,
                          iter=20,
                          sg = 0)

# %% [markdown]
# ## 単語同士の演算
# word2vecにより、単語同士の足し算、引き算が可能になります。
# 以下は単語同士の演算の例ですが、単語のベクトル同士で演算が行われ、結果に最も近い単語が表示されます。
# 単語の表示個数のデフォルトは10です。変更する場合は， `psitive=[単語リスト], topn=表示数` で表示数を指定できます。

# %%
model.wv.most_similar(positive=["猫", "人間"])

# %% [markdown]
# positiveには足し合わせる単語リストを指定します。
# 従って、上記は
# **猫 + 人間**
# を計算しています。
#
# 以下では、
# **人間 + 猫 - 夢**
# を演算しています。

# %%
model.wv.most_similar(positive=["人間", "猫"], negative=["夢"])

# %% [markdown]
# negativeには引く単語のリストを指定します。

# %% [markdown]
# ### 課題3:
# 1. 以下に示す単語同士の演算を行い、結果に最も近い単語を表示しましょう。
# **教師 - 夢**
# 考察：教師から夢を引いたら．．．　それっぽい結果になりましたか？<br>
#
# 2. 次に、自分で考えた単語演算を行なってみましょう。　（このとき，「吾輩は猫である」に出現する単語に限ります。テキストデータやwordcloudで生成したpngファイルを眺めて単語を決めるのも良いかもしれません）<br>
# マークダウン で単語の式を示し，コードを書いて実行してください。
#
# 考察：納得できる結果は得られましたか？
